# %% [markdown]
# # Python Basics for Beginners
#
# Welcome to Python! This notebook covers the fundamental concepts you need to get started with programming.
#
# **Table of Contents:**
# 1. Variables and Data Types
# 2. Operators
# 3. Control Flow (if/else)
# 4. Loops
# 5. Functions
# 6. Lists and Dictionaries
# 7. Practice Exercises

# %% [markdown]
# ## 1. Variables and Data Types
#
# A **variable** is a container for storing data values. Python is dynamically typed, meaning you don't need to declare the type—Python figures it out!

# %%
# Variables and assignment
name = "Alice"           # String (text)
age = 25                 # Integer (whole number)
height = 5.6             # Float (decimal number)
is_student = True        # Boolean (True or False)

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Alice
# 25
# 5.6
# True

# %%
# Check the type of a variable
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# String operations
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name  # Concatenation
print(full_name)

# String methods
print(first_name.upper())     # Convert to uppercase
print(first_name.lower())     # Convert to lowercase
print(len(first_name))        # Length of string
# Out:
# John Doe
# JOHN
# john
# 4

# %% [markdown]
# ## 2. Operators
#
# Operators are used to perform operations on variables and values.

# %%
# Arithmetic operators
a = 10
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulo (remainder): {a} % {b} = {a % b}")
print(f"Exponent: {a} ** {b} = {a ** b}")
# Out:
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Floor Division: 10 // 3 = 3
# Modulo (remainder): 10 % 3 = 1
# Exponent: 10 ** 3 = 1000

# %%
# Comparison operators
x = 5
y = 8

print(f"{x} == {y}: {x == y}")   # Equal to
print(f"{x} != {y}: {x != y}")   # Not equal to
print(f"{x} > {y}: {x > y}")     # Greater than
print(f"{x} < {y}: {x < y}")     # Less than
print(f"{x} >= {y}: {x >= y}")   # Greater than or equal to
print(f"{x} <= {y}: {x <= y}")   # Less than or equal to
# Out:
# 5 == 8: False
# 5 != 8: True
# 5 > 8: False
# 5 < 8: True
# 5 >= 8: False
# 5 <= 8: True

# %%
# Logical operators
a = True
b = False

print(f"{a} and {b}: {a and b}")   # Both must be True
print(f"{a} or {b}: {a or b}")     # At least one must be True
print(f"not {a}: {not a}")          # Reverses the boolean
# Out:
# True and False: False
# True or False: True
# not True: False

# %% [markdown]
# ## 3. Control Flow: if/else/elif
#
# Control flow allows you to execute different code based on conditions.

# %%
# Simple if/else
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
else:
    print("Grade: F")
# Out:
# Grade: B

# %%
# Nested conditions
age = 25
has_license = True

if age >= 18:
    if has_license:
        print("You can drive!")
    else:
        print("You need a driver's license")
else:
    print("You are too young to drive")
# Out:
# You can drive!

# %% [markdown]
# ## 4. Loops
#
# Loops allow you to repeat code multiple times.

# %%
# for loop with range()
print("Counting from 1 to 5:")
for i in range(1, 6):  # range(start, end) - end is exclusive
    print(i)
# Out:
# Counting from 1 to 5:
# 1
# 2
# 3
# 4
# 5

# %%
# for loop with a list
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like cherry

# %%
# while loop
count = 0

while count < 5:
    print(f"Count: {count}")
    count += 1  # count = count + 1
# Out:
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4

# %%
# break and continue
print("Using break:")
for i in range(10):
    if i == 5:
        break  # Exit the loop
    print(i)

print("\nUsing continue:")
for i in range(5):
    if i == 2:
        continue  # Skip this iteration
    print(i)
# Out:
# Using break:
# 0
# 1
# 2
# 3
# 4
#
# Using continue:
# 0
# 1
# 3
# 4

# %% [markdown]
# ## 5. Functions
#
# Functions are reusable blocks of code that perform a specific task.

# %%
# Simple function
def greet():
    print("Hello, World!")

greet()  # Call the function
# Out:
# Hello, World!

# %%
# Function with parameters
def greet_person(name):
    print(f"Hello, {name}!")

greet_person("Alice")
greet_person("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %%
# Function with return value
def add(a, b):
    result = a + b
    return result

sum_result = add(5, 3)
print(f"5 + 3 = {sum_result}")
# Out:
# 5 + 3 = 8

# %%
# Function with default parameters
def introduce(name, age=25):
    print(f"{name} is {age} years old")

introduce("Alice")           # Uses default age
introduce("Bob", 30)         # Provides custom age
# Out:
# Alice is 25 years old
# Bob is 30 years old

# %%
# Function with multiple return values
def get_min_max(numbers):
    minimum = min(numbers)
    maximum = max(numbers)
    return minimum, maximum

my_list = [3, 7, 2, 9, 1]
min_val, max_val = get_min_max(my_list)
print(f"Min: {min_val}, Max: {max_val}")
# Out:
# Min: 1, Max: 9

# %% [markdown]
# ## 6. Lists and Dictionaries
#
# Data structures for storing collections of data.

# %%
# Lists - ordered, mutable collections
numbers = [1, 2, 3, 4, 5]
print(f"List: {numbers}")

# Accessing elements (indexing starts at 0)
print(f"First element: {numbers[0]}")
print(f"Last element: {numbers[-1]}")

# Slicing
print(f"Elements 1-3: {numbers[1:4]}")
# Out:
# List: [1, 2, 3, 4, 5]
# First element: 1
# Last element: 5
# Elements 1-3: [2, 3, 4]

# %%
# List methods
fruits = ["apple", "banana", "cherry"]

fruits.append("date")        # Add to end
print(f"After append: {fruits}")

fruits.insert(1, "blueberry") # Insert at position
print(f"After insert: {fruits}")

fruits.remove("banana")      # Remove specific item
print(f"After remove: {fruits}")

print(f"Length: {len(fruits)}")
# Out:
# After append: ['apple', 'banana', 'cherry', 'date']
# After insert: ['apple', 'blueberry', 'banana', 'cherry', 'date']
# After remove: ['apple', 'blueberry', 'cherry', 'date']
# Length: 4

# %%
# Dictionaries - key-value pairs
person = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}

print(f"Dictionary: {person}")

# Accessing values
print(f"Name: {person['name']}")
print(f"Age: {person['age']}")
# Out:
# Dictionary: {'name': 'Alice', 'age': 25, 'city': 'New York'}
# Name: Alice
# Age: 25

# %%
# Dictionary operations
person = {"name": "Bob", "age": 30}

# Add a new key-value pair
person["email"] = "bob@example.com"
print(f"After adding email: {person}")

# Update a value
person["age"] = 31
print(f"After updating age: {person}")

# Remove a key
del person["email"]
print(f"After deleting email: {person}")

# Check if key exists
print(f"Has 'name': {'name' in person}")
print(f"Has 'email': {'email' in person}")
# Out:
# After adding email: {'name': 'Bob', 'age': 30, 'email': 'bob@example.com'}
# After updating age: {'name': 'Bob', 'age': 31, 'email': 'bob@example.com'}
# After deleting email: {'name': 'Bob', 'age': 31}
# Has 'name': True
# Has 'email': False

# %%
# Iterating through dictionaries
student = {"name": "Charlie", "grade": "A", "score": 95}

# Get keys
print("Keys:", student.keys())

# Get values
print("Values:", student.values())

# Get key-value pairs
print("Items:")
for key, value in student.items():
    print(f"  {key}: {value}")
# Out:
# Keys: dict_keys(['name', 'grade', 'score'])
# Values: dict_values(['Charlie', 'A', 95])
# Items:
#   name: Charlie
#   grade: A
#   score: 95

# %% [markdown]
# ## 7. Practice Exercises
#
# Try these exercises to practice what you've learned!

# %% [markdown]
# ### Exercise 1: Temperature Converter
# Write a function that converts Celsius to Fahrenheit using the formula: F = (C × 9/5) + 32

# %%
# TODO: Write your function here
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# Test it
print(celsius_to_fahrenheit(0))   # Should be 32
print(celsius_to_fahrenheit(100)) # Should be 212
# Out:
# 32.0
# 212.0

# %% [markdown]
# ### Exercise 2: Find the Sum
# Write a function that takes a list of numbers and returns their sum.

# %%
# TODO: Write your function here
def sum_numbers(numbers):
    return sum(numbers)

# Test it
print(sum_numbers([1, 2, 3, 4, 5]))  # Should be 15
print(sum_numbers([10, 20, 30]))     # Should be 60
# Out:
# 15
# 60

# %% [markdown]
# ### Exercise 3: Dictionary Counter
# Create a function that counts the frequency of each letter in a string.

# %%
# TODO: Write your function here
def count_letters(text):
    result = {}
    for letter in text :
        if letter in result :
            result [letter] += 1
        else :
             result [letter] = 1
    return result         

# Test it
result = count_letters("hello")
print(result)  # Should show {"h": 1, "e": 1, "l": 2, "o": 1}
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %% [markdown]
# ### Exercise 4: Filter Even Numbers
# Write a function that takes a list of numbers and returns only the even ones.

# %%
# TODO: Write your function here
def get_even_numbers(numbers):
        return [n for n in numbers if n % 2 == 0]
    

# Test it
print(get_even_numbers([1, 2, 3, 4, 5, 6, 7, 8]))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ### Exercise 5: Rock-Paper-Scissors Game
# Build a simple game where the user plays against the computer.

# %%
import random

def play_rps():
    choices = ["rock", "paper", "scissors"]
    computer = random.choice (choices)
    user = input ("Enter rock, paper, or scissors: ")

    print(f"You chose: {user}")
    print(f"Computer chose: {computer}") 

    if user == computer:
        print ("It's a tie!")
    elif (user == "rock" and computer == "scissors") or \
         (user == "paper" and computer == "rock") or \
         (user == "scissors" and computer == "paper") :
        print("You win!")
    else:
        print ("Computer wins!")
play_rps()
# Out:
# You chose: rock (or paper or scissors)
# Computer chose: scissors
# Computer wins!

# %% [markdown]
# ## Key Takeaways
#
# **Variables** store data with different types (strings, integers, floats, booleans)
#
# **Operators** perform calculations and comparisons
#
# **Control flow** (if/else) lets you make decisions in your code
#
# **Loops** repeat code multiple times
#
# **Functions** organize code into reusable blocks
#
# **Lists and Dictionaries** store multiple values
#
# ## Next Steps
#
# 1. **Practice regularly** - The more you code, the better you get
# 2. **Read error messages** - They tell you what went wrong
# 3. **Explore the Python documentation** - Official docs are your friend
# 4. **Build projects** - Learn by creating real things
# 5. **Join communities** - Connect with other learners
#
# Happy coding!
